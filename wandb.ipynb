# %% [markdown]
# # Hyperparameter Tuning and Performance Optimization:
# ## Gradient Boosting Classifier on Wine Dataset.
#
# **Giamportone, Ariel L.**
#
# **UpgradeHub 2024.**

# %%
import numpy as np
import wandb
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
from sklearn.preprocessing import label_binarize

# %%
wine = load_wine()

# %%
X, y = wine.data , wine.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=357)

# %%
hyperparameters = {
    "learning_rates": [0.005, 0.15, 0.25, 0.55],
    "max_depths": [1,3,5,7],
    "n_estimators": [50, 100, 150],
    "loss_funtions": ["deviance"],
    "subsamples": [0.8 , 1.0],
    "min_samples_splits": [2,4],
    "min_samples_leafs":[1,2]

}

# %%
for lr in hyperparameters["learning_rates"]:
    for max_depth in hyperparameters["max_depths"]:
        for n_estimator in hyperparameters["n_estimators"]:
            for loss_funtion in hyperparameters["loss_funtions"]:
                for subsample in hyperparameters["subsamples"]:
                    for min_samples_split in hyperparameters["min_samples_splits"]:
                        for min_samples_leaf in hyperparameters["min_samples_leafs"]:

                            #Wandb 
                            experiment_name = f"gbm_lr{lr}_depth{max_depth}_est{n_estimator}_loss{loss_funtion}_subsample{subsample}_minsplit{min_samples_split}_minleaf{min_samples_leaf}"
                            wandb.init(project="vinitoupgrade", name= experiment_name, config=hyperparameters)

                            #train 
                            clf = GradientBoostingClassifier(learning_rate=lr, max_depth=max_depth, n_estimators=n_estimator, 
                                                             loss=loss_funtion, subsample=subsample, min_samples_split=min_samples_split, 
                                                             min_samples_leaf=min_samples_leaf, random_state=357, validation_fraction=0.1, 
                                                             n_iter_no_change=5, tol = 0.01)
                            
                            clf.fit(X_train, y_train)

                            #predictions 
                            y_pred = clf.predict(X_test)
                            y_pred_proba = clf.predict_proba(X_test)

                            #log hyp to wandb 
                            wandb.config.learning_rate = lr 
                            wandb.config.max_depth = max_depth
                            wandb.config.n_estimator = n_estimator
                            wandb.config.loss_funtion = loss_funtion
                            wandb.config.subsample = subsample
                            wandb.config.min_samples_split = min_samples_split
                            wandb.config.min_samples_leaf = min_samples_leaf

                            #Calculate perfomance metrics 
                            accuracy = accuracy_score(y_test, y_pred)
                            f1_macro = f1_score(y_test, y_pred, average="macro")
                            y_test_bin = label_binarize(y_test, classes=np.unique(y))
                            y_pred_bin = y_pred_proba.reshape(-1, len(np.unique(y)))
                            roc_auc_macro = roc_auc_score(y_test_bin, y_pred_bin, average="macro", multi_class="ovr")

                            #log metrics wandb
                            wandb.log({"accuracy" : accuracy , "f1_macro" : f1_macro, "roc_auc_macro": roc_auc_macro, "validation_score": clf.train_score_[-1]})

                            #finish
                            wandb.finish()
# Out:
# Finishing last run (ID:s6lxdbjt) before initializing another...
# VBox(children=(Label(value='0.001 MB of 0.006 MB uploaded\r'), FloatProgress(value=0.2028056806373398, max=1.0…
#  View run <strong style="color:#cdcd00">gbm_lr0.005_depth1_est50_lossdeviance_subsample0.8_minsplit2_minleaf1</strong> at: <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/s6lxdbjt' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/s6lxdbjt</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_111810-s6lxdbjt\logs</code>
# Successfully finished last run (ID:s6lxdbjt). Initializing new run:<br/>
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>f:\Upgrade\temario\Modulo 3\Introducción_al_ML\wandb\run-20240130_112428-81v3caqw</code>
# Syncing run <strong><a href='https://wandb.ai/algiamp/vinitoupgrade/runs/81v3caqw' target="_blank">gbm_lr0.005_depth1_est50_lossdeviance_subsample0.8_minsplit2_minleaf1</a></strong> to <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">https://wandb.ai/algiamp/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/81v3caqw' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/81v3caqw</a>
# f:\Upgrade\entorno_upgrade\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.92593</td></tr><tr><td>f1_macro</td><td>0.92451</td></tr><tr><td>roc_auc_macro</td><td>0.99415</td></tr><tr><td>validation_score</td><td>0.80506</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.005_depth1_est50_lossdeviance_subsample0.8_minsplit2_minleaf1</strong> at: <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/81v3caqw' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/81v3caqw</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_112428-81v3caqw\logs</code>
# wandb: Currently logged in as: giamportone1 (algiamp). Use `wandb login --relogin` to force relogin
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>f:\Upgrade\temario\Modulo 3\Introducción_al_ML\wandb\run-20240130_112442-gc6yuns4</code>
# Syncing run <strong><a href='https://wandb.ai/algiamp/vinitoupgrade/runs/gc6yuns4' target="_blank">gbm_lr0.005_depth1_est50_lossdeviance_subsample0.8_minsplit2_minleaf2</a></strong> to <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">https://wandb.ai/algiamp/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/gc6yuns4' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/gc6yuns4</a>
# f:\Upgrade\entorno_upgrade\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.92593</td></tr><tr><td>f1_macro</td><td>0.92451</td></tr><tr><td>roc_auc_macro</td><td>0.99415</td></tr><tr><td>validation_score</td><td>0.80506</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.005_depth1_est50_lossdeviance_subsample0.8_minsplit2_minleaf2</strong> at: <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/gc6yuns4' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/gc6yuns4</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_112442-gc6yuns4\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>f:\Upgrade\temario\Modulo 3\Introducción_al_ML\wandb\run-20240130_112452-s33jf6k9</code>
# Syncing run <strong><a href='https://wandb.ai/algiamp/vinitoupgrade/runs/s33jf6k9' target="_blank">gbm_lr0.005_depth1_est50_lossdeviance_subsample0.8_minsplit4_minleaf1</a></strong> to <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">https://wandb.ai/algiamp/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/s33jf6k9' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/s33jf6k9</a>
# f:\Upgrade\entorno_upgrade\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.92593</td></tr><tr><td>f1_macro</td><td>0.92451</td></tr><tr><td>roc_auc_macro</td><td>0.99415</td></tr><tr><td>validation_score</td><td>0.80506</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.005_depth1_est50_lossdeviance_subsample0.8_minsplit4_minleaf1</strong> at: <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/s33jf6k9' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/s33jf6k9</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_
gbm_lr0.005_depth1_est100_lossdeviance_subsample1.0_minsplit4_minleaf2</a></strong> to <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">https://wandb.ai/algiamp/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/u2ttdjai' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/u2ttdjai</a>
# f:\Upgrade\entorno_upgrade\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.92593</td></tr><tr><td>f1_macro</td><td>0.92451</td></tr><tr><td>roc_auc_macro</td><td>0.99173</td></tr><tr><td>validation_score</td><td>0.61681</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.005_depth1_est100_lossdeviance_subsample1.0_minsplit4_minleaf2</strong> at: <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/u2ttdjai' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/u2ttdjai</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_112703-u2ttdjai\logs</code>
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>f:\Upgrade\temario\Modulo 3\Introducción_al_ML\wandb\run-20240130_112717-xoivn7hr</code>
# Syncing run <strong><a href='https://wandb.ai/algiamp/vinitoupgrade/runs/xoivn7hr' target="_blank">gbm_lr0.005_depth1_est150_lossdeviance_subsample0.8_minsplit2_minleaf1</a></strong> to <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">https://wandb.ai/algiamp/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/xoivn7hr' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/xoivn7hr</a>
# f:\Upgrade\entorno_upgrade\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.006 MB uploaded\r'), FloatProgress(value=0.17763956310679613, max=1.…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.94444</td></tr><tr><td>f1_macro</td><td>0.94135</td></tr><tr><td>roc_auc_macro</td><td>0.99547</td></tr><tr><td>validation_score</td><td>0.47005</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.005_depth1_est150_lossdeviance_subsample0.8_minsplit2_minleaf1</strong> at: <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/xoivn7hr' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/xoivn7hr</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_112717-xoivn7hr\logs</code>
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>f:\Upgrade\temario\Modulo 3\Introducción_al_ML\wandb\run-20240130_112726-bzvf3ipt</code>
# Syncing run <strong><a href='https://wandb.ai/algiamp/vinitoupgrade/runs/bzvf3ipt' target="_blank">gbm_lr0.005_depth1_est150_lossdeviance_subsample0.8_minsplit2_minleaf2</a></strong> to <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">https://wandb.ai/algiamp/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/bzvf3ipt' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/bzvf3ipt</a>
# f:\Upgrade\entorno_upgrade\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.006 MB uploaded\r'), FloatProgress(value=0.18479458523532188, max=1.…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.94444</td></tr><tr><td>f1_macro</td><td>0.94135</td></tr><tr><td>roc_auc_macro</td><td>0.99547</td></tr><tr><td>validation_score</td><td>0.47005</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.005_depth1_est150_lossdeviance_subsample0.8_minsplit2_minleaf2</strong> at: <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/bzvf3ipt' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/bzvf3ipt</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_112726-bzvf3ipt\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>f:\Upgrade\temario\Modulo 3\Introducción_al_ML\wandb\run-20240130_112735-u6yn87yy</code>
# Syncing run <strong><a href='https://wandb.ai/algiamp/vinitoupgrade/runs/u6yn87yy' target="_blank">gbm_lr0.005_depth1_est150_lossdeviance_subsample0.8_minsplit4_minleaf1</a></strong> to <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">https://wandb.ai/algiamp/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/u6yn87yy' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/u6yn87yy</a>
# ...
#  View run <strong style="color:#cdcd00">gbm_lr0.55_depth7_est150_lossdeviance_subsample0.8_minsplit2_minleaf2</strong> at: <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/j8ih0aye' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/j8ih0aye</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_123847-j8ih0aye\logs</code>
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>f:\Upgrade\temario\Modulo 3\Introducción_al_ML\wandb\run-20240130_123857-zupjqmd5</code>
# Syncing run <strong><a href='https://wandb.ai/algiamp/vinitoupgrade/runs/zupjqmd5' target="_blank">gbm_lr0.55_depth7_est150_lossdeviance_subsample0.8_minsplit4_minleaf1</a></strong> to <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">https://wandb.ai/algiamp/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/zupjqmd5' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/zupjqmd5</a>
# f:\Upgrade\entorno_upgrade\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.99901</td></tr><tr><td>validation_score</td><td>8e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.55_depth7_est150_lossdeviance_subsample0.8_minsplit4_minleaf1</strong> at: <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/zupjqmd5' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/zupjqmd5</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_123857-zupjqmd5\logs</code>
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>f:\Upgrade\temario\Modulo 3\Introducción_al_ML\wandb\run-20240130_123908-sc8n8lwc</code>
# Syncing run <strong><a href='https://wandb.ai/algiamp/vinitoupgrade/runs/sc8n8lwc' target="_blank">gbm_lr0.55_depth7_est150_lossdeviance_subsample0.8_minsplit4_minleaf2</a></strong> to <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">https://wandb.ai/algiamp/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/sc8n8lwc' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/sc8n8lwc</a>
# f:\Upgrade\entorno_upgrade\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.99854</td></tr><tr><td>validation_score</td><td>1e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.55_depth7_est150_lossdeviance_subsample0.8_minsplit4_minleaf2</strong> at: <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/sc8n8lwc' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/sc8n8lwc</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_123908-sc8n8lwc\logs</code>
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>f:\Upgrade\temario\Modulo 3\Introducción_al_ML\wandb\run-20240130_123919-qydo5vh4</code>
# Syncing run <strong><a href='https://wandb.ai/algiamp/vinitoupgrade/runs/qydo5vh4' target="_blank">gbm_lr0.55_depth7_est150_lossdeviance_subsample1.0_minsplit2_minleaf1</a></strong> to <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">https://wandb.ai/algiamp/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/qydo5vh4' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/qydo5vh4</a>
# f:\Upgrade\entorno_upgrade\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.92593</td></tr><tr><td>f1_macro</td><td>0.92737</td></tr><tr><td>roc_auc_macro</td><td>0.98264</td></tr><tr><td>validation_score</td><td>0.00017</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.55_depth7_est150_lossdeviance_subsample1.0_minsplit2_minleaf1</strong> at: <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/qydo5vh4' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/qydo5vh4</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_123919-qydo5vh4\logs</code>
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>f:\Upgrade\temario\Modulo 3\Introducción_al_ML\wandb\run-20240130_123929-0vkicb7x</code>
# Syncing run <strong><a href='https://wandb.ai/algiamp/vinitoupgrade/runs/0vkicb7x' target="_blank">gbm_lr0.55_depth7_est150_lossdeviance_subsample1.0_minsplit2_minleaf2</a></strong> to <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">https://wandb.ai/algiamp/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/0vkicb7x' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/0vkicb7x</a>
# f:\Upgrade\entorno_upgrade\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.98148</td></tr><tr><td>f1_macro</td><td>0.98056</td></tr><tr><td>roc_auc_macro</td><td>0.98062</td></tr><tr><td>validation_score</td><td>0.00011</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.55_depth7_est150_lossdeviance_subsample1.0_minsplit2_minleaf2</strong> at: <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/0vkicb7x' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/0vkicb7x</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_123929-0vkicb7x\logs</code>
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>f:\Upgrade\temario\Modulo 3\Introducción_al_ML\wandb\run-20240130_123940-in0gzba1</code>
# Syncing run <strong><a href='https://wandb.ai/algiamp/vinitoupgrade/runs/in0gzba1' target="_blank">gbm_lr0.55_depth7_est150_lossdeviance_subsample1.0_minsplit4_minleaf1</a></strong> to <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">https://wandb.ai/algiamp/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/in0gzba1' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/in0gzba1</a>
# f:\Upgrade\entorno_upgrade\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.94444</td></tr><tr><td>f1_macro</td><td>0.94444</td></tr><tr><td>roc_auc_macro</td><td>0.98389</td></tr><tr><td>validation_score</td><td>0.00018</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.55_depth7_est150_lossdeviance_subsample1.0_minsplit4_minleaf1</strong> at: <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/in0gzba1' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/in0gzba1</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_123940-in0gzba1\logs</code>
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>f:\Upgrade\temario\Modulo 3\Introducción_al_ML\wandb\run-20240130_123950-nnopwbdb</code>
# Syncing run <strong><a href='https://wandb.ai/algiamp/vinitoupgrade/runs/nnopwbdb' target="_blank">gbm_lr0.55_depth7_est150_lossdeviance_subsample1.0_minsplit4_minleaf2</a></strong> to <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/algiamp/vinitoupgrade' target="_blank">https://wandb.ai/algiamp/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/nnopwbdb' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/nnopwbdb</a>
# f:\Upgrade\entorno_upgrade\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.98148</td></tr><tr><td>f1_macro</td><td>0.98056</td></tr><tr><td>roc_auc_macro</td><td>0.98062</td></tr><tr><td>validation_score</td><td>0.00011</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.55_depth7_est150_lossdeviance_subsample1.0_minsplit4_minleaf2</strong> at: <a href='https://wandb.ai/algiamp/vinitoupgrade/runs/nnopwbdb' target="_blank">https://wandb.ai/algiamp/vinitoupgrade/runs/nnopwbdb</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_123950-nnopwbdb\logs</code>
